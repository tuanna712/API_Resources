# %%
import requests

# URL of your FastAPI server
url = "http://103.106.104.72:9998/chat/"

# The message you want to send
message = "Hello, FastAPI!"

# Send a POST request to the server
response = requests.post(url, json={"input_message": message})

# Print the response from the server
print(response.json())
# Out:
# {'detail': [{'type': 'missing', 'loc': ['body', 'input'], 'msg': 'Field required', 'input': {'input_message': 'Hello, FastAPI!'}, 'url': 'https://errors.pydantic.dev/2.6/v/missing'}]}

# %%
from app.functions import KGSearch
api = ""
KGS = KGSearch(api)
ans = KGS.kg_chat("Van hoa VPI la gi?")
ans
